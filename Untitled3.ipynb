# %% [markdown]
# <a href="https://colab.research.google.com/github/nayanbanarase/project7/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')
df
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull()
# Out:
#     Experience Years  Salary
# 0              False   False
# 1              False   False
# 2              False   False
# 3              False   False
# 4              False   False
# 5              False   False
# 6              False   False
# 7              False   False
# 8              False   False
# 9              False   False
# 10             False   False
# 11             False   False
# 12             False   False
# 13             False   False
# 14             False   False
# 15             False   False
# 16             False   False
# 17             False   False
# 18             False   False
# 19             False   False
# 20             False   False
# 21             False   False
# 22             False   False
# 23             False   False
# 24             False   False
# 25             False   False
# 26             False   False
# 27             False   False
# 28             False   False
# 29             False   False
# 30             False   False
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = df['Experience Years']
ypoints = df['Salary']

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = df['Experience Years']
ypoints = df['Salary']
plt.title('experience vs salary')
plt.xlabel('experience years')
plt.ylabel('salary')

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = df['Experience Years']
ypoints = df['Salary']
plt.title('experience vs salary')
plt.xlabel('experience years')
plt.ylabel('salary')
plt.scatter(xpoints, ypoints)

plt.plot(xpoints, ypoints)
plt.show()

# %%
df.shape
# Out:
# (40, 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df['Experience Years'].values.reshape(-1, 1)
y = df['Salary']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2529)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((32, 1), (8, 1), (32,), (8,))

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 96.10384373131336

# %%
lr.predict([[10]])
# Out:
# array([120326.83668364])

# %%
year=float(input("enter your Experience in year:"))
salary=lr.predict([[year]])
print(salary)
# Out:
# enter your Experience in year:7.5
# [96831.34203827]

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = df['Experience Years']
ypoints = df['Salary']
plt.title('experience vs salary')
plt.xlabel('experience years')
plt.ylabel('salary')
plt.scatter(xpoints, ypoints)
plt.plot(x,lr.predict(x),color="red")
plt.plot(xpoints, ypoints)
plt.show()
